# %%
import pandas as pd


google=pd.read_csv("pokemon.csv", squeeze=True)
google
# Out:
#        #                    Name    Type 1  Type 2   HP  Attack  Defense  \
# 0      1               Bulbasaur     Grass  Poison   45      49       49
# 1      2                 Ivysaur     Grass  Poison   60      62       63
# 2      3                Venusaur     Grass  Poison   80      82       83
# 3      4           Mega Venusaur     Grass  Poison   80     100      123
# 4      5              Charmander      Fire     NaN   39      52       43
# 5      6              Charmeleon      Fire     NaN   58      64       58
# 6      7               Charizard      Fire  Flying   78      84       78
# 7      8        Mega Charizard X      Fire  Dragon   78     130      111
# 8      9        Mega Charizard Y      Fire  Flying   78     104       78
# 9     10                Squirtle     Water     NaN   44      48       65
# 10    11               Wartortle     Water     NaN   59      63       80
# 11    12               Blastoise     Water     NaN   79      83      100
# ...

# %%
google.sort_values("Name",ascending=False)
# Out:
#        #                    Name    Type 1    Type 2   HP  Attack  Defense  \
# 794  795      Zygarde Half Forme    Dragon    Ground  108     100      121
# 695  696                Zweilous      Dark    Dragon   72      85       70
# 46    47                   Zubat    Poison    Flying   40      45       35
# 631  632                   Zorua      Dark       NaN   40      65       40
# 632  633                 Zoroark      Dark       NaN   60     105       60
# 286  287               Zigzagoon    Normal       NaN   38      30       41
# 707  708                  Zekrom    Dragon  Electric  100     150      120
# 582  583               Zebstrika  Electric       NaN   75     100       63
# 157  158                  Zapdos  Electric    Flying   90      90       85
# 367  368                Zangoose    Normal       NaN   73     115       60
# 793  794                 Yveltal      Dark    Flying  126     131       95
# ...

# %%
google.sort_values("Attack").fillna("helllo")
# Out:
#        #                   Name   Type 1    Type 2   HP  Attack  Defense  \
# 488  489                Happiny   Normal    helllo  100       5        5
# 121  122                Chansey   Normal    helllo  250       5        5
# 230  231                Shuckle      Bug      Rock   20      10      230
# 261  262                Blissey   Normal    helllo  255      10       10
# 139  140               Magikarp    Water    helllo   20      10       55
# 381  382                 Feebas    Water    helllo   20      15       20
# 68    69                   Abra  Psychic    helllo   25      20       15
# 508  509                Mantyke    Water    Flying   45      20       50
# 179  180                 Ledyba      Bug    Flying   40      20       30
# 189  190                 Togepi    Fairy    helllo   35      20       65
# 254  255               Smeargle   Normal    helllo   55      20       35
# 198  199                 Marill    Water     Fairy   70      20       50
# ...

# %%
google.sort_values("Attack",na_position='first')
# Out:
#        #                   Name   Type 1    Type 2   HP  Attack  Defense  \
# 488  489                Happiny   Normal       NaN  100       5        5
# 121  122                Chansey   Normal       NaN  250       5        5
# 230  231                Shuckle      Bug      Rock   20      10      230
# 261  262                Blissey   Normal       NaN  255      10       10
# 139  140               Magikarp    Water       NaN   20      10       55
# 381  382                 Feebas    Water       NaN   20      15       20
# 68    69                   Abra  Psychic       NaN   25      20       15
# 508  509                Mantyke    Water    Flying   45      20       50
# 179  180                 Ledyba      Bug    Flying   40      20       30
# 189  190                 Togepi    Fairy       NaN   35      20       65
# 254  255               Smeargle   Normal       NaN   55      20       35
# 198  199                 Marill    Water     Fairy   70      20       50
# ...
