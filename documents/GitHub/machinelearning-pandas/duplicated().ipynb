# %%
import pandas as pd

df=pd.read_csv("100 Records.csv")
df

df.sort_values('First Name',inplace=True)
df.head()
# Out:
#     Emp ID Name Prefix First Name Middle Initial Last Name Gender  \
# 36  218791         Mr.      Aaron              N     Price      M
# 43  247137         Mr.       Alan              E    Rivera      M
# 41  227922        Hon.     Amanda              M    Hughes      F
# 31  893212         Ms.        Amy              B    Howard      F
# 66  183071        Drs.     Andrea              P    Garcia      F
#
#                           E Mail  Father's Name    Mother's Name  \
# 36            aaron.price@bp.com  Michael Price      Diana Price
# 43         alan.rivera@apple.com   Bobby Rivera  Jennifer Rivera
# 41  amanda.hughes@rediffmail.com     Roy Hughes   Cynthia Hughes
# 31            amy.howard@aol.com   James Howard  Virginia Howard
# 66         andrea.garcia@aol.com    Mark Garcia    Nicole Garcia
#
#    Mother's Maiden Name  ...          SSN    Phone No.     Place Name  \
# 36               Torres  ...  491-29-5152  219-287-8926       Eckerty
# ...

# %%
mask=df["First Name"].duplicated()
df[mask].head()
# Out:
#     Emp ID Name Prefix First Name Middle Initial Last Name Gender  \
# 51  447813        Mrs.        Ann              Q   Coleman      F
# 25  477253        Mrs.       Anne              L   Russell      F
# 1   940761         Ms.     Brenda              S  Robinson      F
# 7   380086        Mrs.      Carol              V    Murphy      F
# 79  325319        Hon.    Carolyn              F     Price      F
#
#                        E Mail     Father's Name      Mother's Name  \
# 51        ann.coleman@ibm.com    Harold Coleman       Tina Coleman
# 25       anne.russell@ibm.com     Jimmy Russell  Stephanie Russell
# 1   brenda.robinson@gmail.com  Raymond Robinson      Judy Robinson
# 7      carol.murphy@gmail.com     Eugene Murphy   Katherine Murphy
# 79    carolyn.price@yahoo.com       Kevin Price     Patricia Price
#
#    Mother's Maiden Name  ...          SSN    Phone No.    Place Name  \
# 51               Walker  ...  027-92-0557  319-994-4179      Hancock
# ...

# %%
mask=df["First Name"].duplicated(keep="last")
df[mask].head()
# Out:
#     Emp ID Name Prefix First Name Middle Initial Last Name Gender  \
# 56  904898        Drs.        Ann              Q    Cooper      F
# 57  515103         Ms.       Anne              A     Perez      F
# 29  335732         Ms.     Brenda              M    Butler      F
# 20  979607         Ms.      Carol              J   Edwards      F
# 24  560455         Ms.    Carolyn              V     Hayes      F
#
#                          E Mail   Father's Name   Mother's Name  \
# 56    ann.cooper@exxonmobil.com   Harold Cooper  Mildred Cooper
# 57     anne.perez@sbcglobal.net   Douglas Perez     Doris Perez
# 29      brenda.butler@gmail.com  Phillip Butler    Joyce Butler
# 20        carol.edwards@msn.com   Shawn Edwards   Susan Edwards
# 24  carolyn.hayes@hotmail.co.uk     Jimmy Hayes      Sara Hayes
#
#    Mother's Maiden Name  ...          SSN    Phone No.    Place Name  \
# 56             Williams  ...  219-89-6310  406-278-6460        Arlee
# ...

# %%
mask=~df["First Name"].duplicated(keep=False)
df[mask].head()
# Out:
#     Emp ID Name Prefix First Name Middle Initial Last Name Gender  \
# 36  218791         Mr.      Aaron              N     Price      M
# 43  247137         Mr.       Alan              E    Rivera      M
# 41  227922        Hon.     Amanda              M    Hughes      F
# 31  893212         Ms.        Amy              B    Howard      F
# 66  183071        Drs.     Andrea              P    Garcia      F
#
#                           E Mail  Father's Name    Mother's Name  \
# 36            aaron.price@bp.com  Michael Price      Diana Price
# 43         alan.rivera@apple.com   Bobby Rivera  Jennifer Rivera
# 41  amanda.hughes@rediffmail.com     Roy Hughes   Cynthia Hughes
# 31            amy.howard@aol.com   James Howard  Virginia Howard
# 66         andrea.garcia@aol.com    Mark Garcia    Nicole Garcia
#
#    Mother's Maiden Name  ...          SSN    Phone No.     Place Name  \
# 36               Torres  ...  491-29-5152  219-287-8926       Eckerty
# ...

# %%
import pandas as pd

df=pd.read_csv("100 Records.csv")
df
# Out:
#     Emp ID Name Prefix First Name Middle Initial   Last Name Gender  \
# 0   677509        Drs.       Lois              H      Walker      F
# 1   940761         Ms.     Brenda              S    Robinson      F
# 2   428945         Dr.        Joe              W    Robinson      M
# 3   408351        Drs.      Diane              I       Evans      F
# 4   193819         Mr.   Benjamin              R     Russell      M
# 5   499687         Mr.    Patrick              F      Bailey      M
# 6   539712         Ms.      Nancy              T       Baker      F
# 7   380086        Mrs.      Carol              V      Murphy      F
# 8   477616        Hon.    Frances              B       Young      F
# 9   162402        Hon.      Diana              T    Peterson      F
# 10  231469         Mr.      Ralph              L      Flores      M
# 11  153989       Prof.       Jack              C   Alexander      M
# 12  386158        Mrs.    Melissa              Q        King      F
# ...

# %%
df.sort_values("Last Name", inplace=True)
df.head()
# Out:
#     Emp ID Name Prefix First Name Middle Initial  Last Name Gender  \
# 86  533952         Ms.      Kelly              R      Adams      F
# 84  802554         Mr.       Ryan              V  Alexander      M
# 11  153989       Prof.       Jack              C  Alexander      M
# 88  844177         Ms.   Margaret              T      Allen      F
# 70  915638         Dr.      Jason              W   Anderson      M
#
#                       E Mail      Father's Name        Mother's Name  \
# 86        kelly.adams@bp.com         Eric Adams         Janice Adams
# 84  ryan.alexander@shell.com  William Alexander  Elizabeth Alexander
# 11  jack.alexander@gmail.com   Samuel Alexander     Sharon Alexander
# 88  margaret.allen@gmail.com      Michael Allen          Karen Allen
# 70  jason.anderson@gmail.com   Brandon Anderson       Julia Anderson
#
#    Mother's Maiden Name  ...          SSN    Phone No.      Place Name  \
# 86               Brooks  ...  474-55-8101  405-418-0037           Meno
# ...

# %%
mask=~df["Last Name"].duplicated(keep=False)
df[mask]
# Out:
#     Emp ID Name Prefix First Name Middle Initial  Last Name Gender  \
# 86  533952         Ms.      Kelly              R      Adams      F
# 88  844177         Ms.   Margaret              T      Allen      F
# 70  915638         Dr.      Jason              W   Anderson      M
# 5   499687         Mr.    Patrick              F     Bailey      M
# 6   539712         Ms.      Nancy              T      Baker      F
# 72  951225         Ms.   Margaret              N     Brooks      F
# 40  923947         Ms.       Mary              G     Bryant      F
# 42  265813        Hon.       Jack              E   Campbell      M
# 51  447813        Mrs.        Ann              Q    Coleman      F
# 38  726264        Hon.       Carl              N    Collins      M
# 45  226714        Drs.      Nancy              L      Davis      F
# 15  528509        Hon.      Paula              G       Diaz      F
# 3   408351        Drs.      Diane              I      Evans      F
# ...
