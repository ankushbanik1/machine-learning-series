# %%
import pandas as pd

df=pd.read_csv("100 Records.csv")
df

df.sort_values('First Name',inplace=True)
df.head()
# Out:
#     Emp ID Name Prefix First Name Middle Initial Last Name Gender  \
# 36  218791         Mr.      Aaron              N     Price      M
# 43  247137         Mr.       Alan              E    Rivera      M
# 41  227922        Hon.     Amanda              M    Hughes      F
# 31  893212         Ms.        Amy              B    Howard      F
# 66  183071        Drs.     Andrea              P    Garcia      F
#
#                           E Mail  Father's Name    Mother's Name  \
# 36            aaron.price@bp.com  Michael Price      Diana Price
# 43         alan.rivera@apple.com   Bobby Rivera  Jennifer Rivera
# 41  amanda.hughes@rediffmail.com     Roy Hughes   Cynthia Hughes
# 31            amy.howard@aol.com   James Howard  Virginia Howard
# 66         andrea.garcia@aol.com    Mark Garcia    Nicole Garcia
#
#    Mother's Maiden Name  ...          SSN    Phone No.     Place Name  \
# 36               Torres  ...  491-29-5152  219-287-8926       Eckerty
# ...

# %%
mas=df.drop_duplicates(subset=["First Name" ,"E Mail"],keep=False)
len(mas)
df
# Out:
#     Emp ID Name Prefix   First Name Middle Initial   Last Name Gender  \
# 36  218791         Mr.        Aaron              N       Price      M
# 43  247137         Mr.         Alan              E      Rivera      M
# 41  227922        Hon.       Amanda              M      Hughes      F
# 31  893212         Ms.          Amy              B      Howard      F
# 66  183071        Drs.       Andrea              P      Garcia      F
# 56  904898        Drs.          Ann              Q      Cooper      F
# 51  447813        Mrs.          Ann              Q     Coleman      F
# 57  515103         Ms.         Anne              A       Perez      F
# 25  477253        Mrs.         Anne              L     Russell      F
# 59  750173         Mr.      Antonio              R     Roberts      M
# 4   193819         Mr.     Benjamin              R     Russell      M
# 29  335732         Ms.       Brenda              M      Butler      F
# ...
