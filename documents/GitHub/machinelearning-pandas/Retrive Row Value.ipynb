# %%
import pandas as pd

bond= pd.read_csv("jems.csv", index_col="Film")
bond.sort_index(inplace=True)
bond.head()
# Out:
#                       Year  Years lapse      Bond actor  \
# Film
# A View to a Kill      1985          2.0     Roger Moore
# Casino Royale         2006          4.0    Daniel Craig
# Diamonds Are Forever  1971          2.0    Sean Connery
# Die Another Day       2002          3.0  Pierce Brosnan
# Dr. No                1962          NaN    Sean Connery
#
#                       Bond actor appearance  Villians Dispatched  \
# Film
# A View to a Kill                          7                    5
# Casino Royale                             1                   11
# Diamonds Are Forever                      6                    7
# Die Another Day                           4                   31
# Dr. No                                    1                    4
#
#                       Others' Dispatched  Total Dispatched  \
# Film
# A View to a Kill                      57                62
# Casino Royale                         11                22
# ...

# %%
bond.iloc[11:23]
bond.iloc[11:23:2]
# Out:
#                                  Year  Years lapse      Bond actor  \
# Film
# Moonraker                        1979          2.0     Roger Moore
# On Her Majesty's Secret Service  1969          2.0  George Lazenby
# Skyfall                          2012          4.0    Daniel Craig
# The Man with the Golden Gun      1974          1.0     Roger Moore
# The World is Not Enough          1999          2.0  Pierce Brosnan
# Tomorrow Never Dies              1997          2.0  Pierce Brosnan
#
#                                  Bond actor appearance  Villians Dispatched  \
# Film
# Moonraker                                            4                   12
# On Her Majesty's Secret Service                      1                    5
# Skyfall                                              3                   26
# The Man with the Golden Gun                          2                    1
# The World is Not Enough                              3                   27
# ...

# %%
bond.ix[11:23]
# Out:
# c:\users\ankush\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
#                                  Year  Years lapse      Bond actor  \
# Film
# Moonraker                        1979          2.0     Roger Moore
# Octopussy                        1983          2.0     Roger Moore
# On Her Majesty's Secret Service  1969          2.0  George Lazenby
# Quantum of Solace                2008          2.0    Daniel Craig
# Skyfall                          2012          4.0    Daniel Craig
# The Living Daylights             1987          2.0  Timothy Dalton
# The Man with the Golden Gun      1974          1.0     Roger Moore
# ...
