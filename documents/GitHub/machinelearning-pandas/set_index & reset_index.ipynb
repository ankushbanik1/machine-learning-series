# %%
import pandas as pd

df=pd.read_csv("jems.csv")
df.set_index("Film", inplace=True)
df.reset_index()
# Out:
#                                Film  Year  Years lapse      Bond actor  \
# 0                            Dr. No  1962          NaN    Sean Connery
# 1             From Russia With Love  1963          1.0    Sean Connery
# 2                        Goldfinger  1964          1.0    Sean Connery
# 3                       Thunderball  1965          1.0    Sean Connery
# 4               You Only Live Twice  1967          2.0    Sean Connery
# 5   On Her Majesty's Secret Service  1969          2.0  George Lazenby
# 6              Diamonds Are Forever  1971          2.0    Sean Connery
# 7                  Live and Let Die  1973          2.0     Roger Moore
# 8       The Man with the Golden Gun  1974          1.0     Roger Moore
# 9              The Spy Who Loved Me  1977          3.0     Roger Moore
# 10                        Moonraker  1979          2.0     Roger Moore
# 11               For Your Eyes Only  1981          2.0     Roger Moore
# ...

# %%
import pandas as pd

df=pd.read_csv("jems.csv")
df.set_index("Year", inplace=True)
df.reset_index()
# Out:
#     Year                             Film  Years lapse      Bond actor  \
# 0   1962                           Dr. No          NaN    Sean Connery
# 1   1963            From Russia With Love          1.0    Sean Connery
# 2   1964                       Goldfinger          1.0    Sean Connery
# 3   1965                      Thunderball          1.0    Sean Connery
# 4   1967              You Only Live Twice          2.0    Sean Connery
# 5   1969  On Her Majesty's Secret Service          2.0  George Lazenby
# 6   1971             Diamonds Are Forever          2.0    Sean Connery
# 7   1973                 Live and Let Die          2.0     Roger Moore
# 8   1974      The Man with the Golden Gun          1.0     Roger Moore
# 9   1977             The Spy Who Loved Me          3.0     Roger Moore
# 10  1979                        Moonraker          2.0     Roger Moore
# 11  1981               For Your Eyes Only          2.0     Roger Moore
# ...

# %%
# Out:
#     Year      Bond actor  Bond actor appearance  Villians Dispatched  \
# 0   1962    Sean Connery                      1                    4
# 1   1963    Sean Connery                      2                   11
# 2   1964    Sean Connery                      3                    9
# 3   1965    Sean Connery                      4                   20
# 4   1967    Sean Connery                      5                   21
# 5   1969  George Lazenby                      1                    5
# 6   1971    Sean Connery                      6                    7
# 7   1973     Roger Moore                      1                    8
# 8   1974     Roger Moore                      2                    1
# 9   1977     Roger Moore                      3                   31
# 10  1979     Roger Moore                      4                   12
# 11  1981     Roger Moore                      5                   18
# 12  1983     Roger Moore                      6                   15
# ...

# %%
df.set_index("Bond actor",inplace=True)
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\users\ankush\appdata\local\programs\python\python37\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Bond actor'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-19-e6675583d959> in <module>
# ...
