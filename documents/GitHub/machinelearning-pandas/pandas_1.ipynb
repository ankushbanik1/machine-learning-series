# %%
import pandas as pd
p=pd.read_csv("pokemon.csv", index_col="Name",squeeze=(True))

p
# Out:
#                           #    Type 1  Type 2   HP  Attack  Defense  Sp. Atk  \
# Name
# Bulbasaur                 1     Grass  Poison   45      49       49       65
# Ivysaur                   2     Grass  Poison   60      62       63       80
# Venusaur                  3     Grass  Poison   80      82       83      100
# Mega Venusaur             4     Grass  Poison   80     100      123      122
# Charmander                5      Fire     NaN   39      52       43       60
# Charmeleon                6      Fire     NaN   58      64       58       80
# Charizard                 7      Fire  Flying   78      84       78      109
# Mega Charizard X          8      Fire  Dragon   78     130      111      130
# Mega Charizard Y          9      Fire  Flying   78     104       78      159
# Squirtle                 10     Water     NaN   44      48       65       50
# Wartortle                11     Water     NaN   59      63       80       65
# ...

# %%
p.head(8)
# Out:
#                   # Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# Name
# Bulbasaur         1  Grass  Poison  45      49       49       65       65
# Ivysaur           2  Grass  Poison  60      62       63       80       80
# Venusaur          3  Grass  Poison  80      82       83      100      100
# Mega Venusaur     4  Grass  Poison  80     100      123      122      120
# Charmander        5   Fire     NaN  39      52       43       60       50
# Charmeleon        6   Fire     NaN  58      64       58       80       65
# Charizard         7   Fire  Flying  78      84       78      109       85
# Mega Charizard X  8   Fire  Dragon  78     130      111      130       85
#
#                   Speed  Generation  Legendary
# Name
# Bulbasaur            45           1      False
# Ivysaur              60           1      False
# Venusaur             80           1      False
# Mega Venusaur        80           1      False
# Charmander           65           1      False
# ...

# %%
p.tail()
# Out:
#                   #   Type 1 Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# Name
# Diancie         796     Rock  Fairy  50     100      150      100      150
# Mega Diancie    797     Rock  Fairy  50     160      110      160      110
# Hoopa Confined  798  Psychic  Ghost  80     110       60      150      130
# Hoopa Unbound   799  Psychic   Dark  80     160       60      170      130
# Volcanion       800     Fire  Water  80     110      120      130       90
#
#                 Speed  Generation  Legendary
# Name
# Diancie            50           6       True
# Mega Diancie      110           6       True
# Hoopa Confined     70           6       True
# Hoopa Unbound      80           6       True
# Volcanion          70           6       True

# %%
p.get(key='Diancie', default="this is a dflt  value")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-22-5d10e0168d95> in <module>
# ----> 1 p.get(key='Diancie', default="this is a dflt  value")
#
# AttributeError: 'list' object has no attribute 'get'

# %%
google =pd.read_csv("GOOGL.csv", squeeze=True)
google.min()
# Out:
# Date         2009-05-22
# Open            196.171
# High            199.525
# Low             195.195
# Close           196.947
# Adj Close       196.947
# Volume           520600
# dtype: object
